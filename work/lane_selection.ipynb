# %% [markdown]
# <a href="https://colab.research.google.com/github/Jyotiii49/flyrank-ml-internship/blob/main/work/lane_selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lane 1: Ranking Signal Analysis
# 1. Lane Chosen
# **bold text**
# Lane: Ranking Signal Analysis

# %% [markdown]
# **### 2. Search Question**
#
# Question:
#
# Which safe content and search signals are associated with higher search visibility, clicks, and engagement?

# %% [markdown]
# **3. Unit of Analysis**
#
# Unit of Analysis:
#
# The unit of analysis is an individual webpage (content page). Each row in the dataset represents one webpage, and I will analyze how its content and search signals relate to its search performance.

# %% [markdown]
# **4. Expected Output**
#
# Output:
#
# The project will produce a signal analysis report showing which content and search features are associated with better search performance. The output will include summary statistics, visualizations, feature importance (if applicable), and practical recommendations for improving webpage visibility.

# %% [markdown]
# **5. Action Someone Could Take**
#
# Action:
#
# Website owners and SEO teams can use these findings to improve webpages by focusing on the content and search signals that are associated with higher visibility and more clicks. These insights can help prioritize SEO improvements.

# %% [markdown]
# **6. Cost of a Wrong Recommendation**
#
# Cost of Wrong Recommendation:
#
# If the recommendations are incorrect, businesses may spend time and resources optimizing the wrong content. This could reduce search performance, waste effort, and delay improvements in website traffic.

# %% [markdown]
# **7. Why Data or Machine Learning Can Help**
#
# Why Data/ML?
#
# Search performance depends on many factors working together. Data analysis and machine learning can identify patterns and relationships that are difficult to discover manually. These methods help analyze multiple features simultaneously and generate evidence-based insights.

# %% [markdown]
# 8**. Load the Dataset**

# %%
import pandas as pd
import os

# Search for CSV files in the data folder
for root, dirs, files in os.walk("data"):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /content
# ['.config', 'sample_data']

# %%
# !git clone https://github.com/jyotiii49/flyrank-ml-internship.git
# Out:
# Cloning into 'flyrank-ml-internship'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 117 (delta 33), reused 80 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (117/117), 1.84 MiB | 6.90 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
import os

os.chdir("flyrank-ml-internship")
print(os.getcwd())
print(os.listdir())
# Out:
# /content/flyrank-ml-internship
# ['notebooks', 'work', 'AGENTS.md', 'skills', 'DATA_USE.md', '02_your_first_readable_model.ipynb', 'scripts', '.github', 'LICENSE', '.gitignore', 'outputs', 'CLAUDE.md', 'data', 'README.md', 'submission', '.git', 'GUIDE.md', 'SETUP.md', 'requirements.txt', 'docs']

# %%
import os

print(os.listdir("data"))
# Out:
# ['raw']

# %%
print(os.listdir("data/raw"))
# Out:
# ['content_refresh_anonymized.csv']

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (30000, 44)

# %%
print(df.columns)
# Out:
# Index(['content_id', 'client_id', 'search_volume', 'competition',
#        'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count',
#        'char_count', 'provider_used', 'model_used', 'impressions_90d',
#        'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d',
#        'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d',
#        'days_with_impressions', 'days_with_sessions', 'impressions_last_30d',
#        'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d',
#        'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier',
#        'age_tier_order', 'days_since_last_update', 'freshness_tier',
#        'word_count_tier', 'char_count_tier', 'ctr', 'avg_position',
#        'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier',
#        'position_tier', 'trend_direction', 'trend_pct'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   content_id              30000 non-null  object
#  1   client_id               30000 non-null  object
#  2   search_volume           27532 non-null  float64
#  3   competition             27532 non-null  float64
#  4   competition_level       27390 non-null  object
#  5   cpc                     27532 non-null  float64
#  6   content_type            30000 non-null  object
#  7   main_intent             27626 non-null  object
#  8   word_count              22301 non-null  float64
#  9   char_count              22301 non-null  float64
#  10  provider_used           8562 non-null   object
#  11  model_used              24267 non-null  object
#  12  impressions_90d         30000 non-null  int64
#  13  clicks_90d              30000 non-null  int64
# ...

# %%
df.describe()
# Out:
#        search_volume   competition           cpc    word_count     char_count  \
# count   27532.000000  27532.000000  27532.000000  22301.000000   22301.000000
# mean      158.882391      0.146954      0.485342   3107.760325   20665.277835
# std      1518.270825      0.285241      2.101560   1452.382598   10115.344042
# min         0.000000      0.000000      0.000000      8.000000      40.000000
# 25%         0.000000      0.000000      0.000000   2413.000000   15644.000000
# 50%        10.000000      0.000000      0.000000   2877.000000   19116.000000
# 75%        20.000000      0.130000      0.000000   3666.000000   24011.000000
# max     74000.000000      1.000000    100.360000   9546.000000  111158.000000
#
#        impressions_90d    clicks_90d  pageviews_90d  sessions_90d  \
# count     30000.000000  30000.000000   30000.000000  30000.000000
# mean       5200.366300     16.097333      49.942467     37.066633
# std       16838.019547     75.076958     152.101430    107.069131
# ...

# %%
print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (30000, 44)

# %%
print(df.columns)
# Out:
# Index(['content_id', 'client_id', 'search_volume', 'competition',
#        'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count',
#        'char_count', 'provider_used', 'model_used', 'impressions_90d',
#        'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d',
#        'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d',
#        'days_with_impressions', 'days_with_sessions', 'impressions_last_30d',
#        'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d',
#        'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier',
#        'age_tier_order', 'days_since_last_update', 'freshness_tier',
#        'word_count_tier', 'char_count_tier', 'ctr', 'avg_position',
#        'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier',
#        'position_tier', 'trend_direction', 'trend_pct'],
#       dtype='object')

# %%
print("Dataset Shape:", df.shape)
print("Average 90-Day Impressions:", df["impressions_90d"].mean())
print("Average 90-Day Clicks:", df["clicks_90d"].mean())
print("Average Position:", df["avg_position"].mean())
print("Average CTR:", df["ctr"].mean())
# Out:
# Dataset Shape: (30000, 44)
# Average 90-Day Impressions: 5200.3663
# Average 90-Day Clicks: 16.097333333333335
# Average Position: 16.342380000000002
# Average CTR: 0.5107333333333334

# %% [markdown]
# ## Evidence from the Starter Dataset
#
#
# The average number of impressions over the last 90 days is **(write the value)**.
#
# The average number of clicks over the last 90 days is **(write the value)**.
#
# The average search position is **(write the value)**.
#
# These statistics show that the dataset contains meaningful variation in search performance, making it suitable for analyzing which content and search signals are associated with better visibility and engagement.

# %% [markdown]
# ## Why I Chose Lane 1
#
# I selected the Ranking Signal Analysis lane because I want to understand which content and search signals are associated with better search visibility, clicks, and engagement. These insights can help website owners and SEO teams make better content improvement decisions.
#
# The results of this analysis will be observational, meaning they show associations in the data rather than proving that one factor directly causes another.

# %% [markdown]
# ## Initial Observation
#
# The dataset contains webpages with different levels of impressions, clicks, CTR, and average position. This variation suggests that some content and search signals may be associated with stronger search performance, making this a good topic for further analysis.
